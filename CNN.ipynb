# %%
# Download dataset
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-11-26 06:13:47--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.210.128, 173.194.215.128, 173.194.216.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.210.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   194MB/s    in 0.3s
#
# 2021-11-26 06:13:48 (194 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# Ekstrak dataset

import os
import zipfile

local_zip = '/tmp/Datasetsatu.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
# Definisikan path untuk data train dan data validation

base_dir = '/tmp/Datasetsatu'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
# Out:
# Train Data =  (80, 150, 150, 3)
# Train Label =  (80,)
# Validation Data =  (21, 150, 150, 3)
# Validation Label =  (21,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [188 184 179]
# Data setelah di-normalisasi  [0.7372549  0.72156864 0.7019608 ]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten

# %%
# Feature Extraction Layer
model = Sequential()

model.add(InputLayer(input_shape=[150,150,3]))
model.add(Conv2D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, padding='same'))
model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, padding='same'))
model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=2, padding='same'))
model.add(Flatten())

# %%
# Fully Connected Layer
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Print model summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 23104)             0
#
#  dense (Dense)               (None, 128)               2957440
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,981,153
# Trainable params: 2,981,153
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Compile model
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(lr=0.001), 
              loss='binary_crossentropy', 
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=15, validation_data=(x_val, y_val))
# Out:
# Epoch 1/15
# 4/4 [==============================] - 3s 554ms/step - loss: 0.8282 - acc: 0.4750 - val_loss: 0.4215 - val_acc: 0.9524
# Epoch 2/15
# 4/4 [==============================] - 2s 478ms/step - loss: 0.2788 - acc: 1.0000 - val_loss: 0.1098 - val_acc: 1.0000
# Epoch 3/15
# 4/4 [==============================] - 2s 498ms/step - loss: 0.0516 - acc: 1.0000 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 4/15
# 4/4 [==============================] - 2s 489ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 5/15
# 4/4 [==============================] - 2s 488ms/step - loss: 1.1586e-04 - acc: 1.0000 - val_loss: 2.4214e-04 - val_acc: 1.0000
# Epoch 6/15
# 4/4 [==============================] - 2s 484ms/step - loss: 1.1093e-05 - acc: 1.0000 - val_loss: 1.2973e-04 - val_acc: 1.0000
# Epoch 7/15
# 4/4 [==============================] - 2s 488ms/step - loss: 5.5136e-06 - acc: 1.0000 - val_loss: 1.2525e-04 - val_acc: 1.0000
# Epoch 8/15
# 4/4 [==============================] - 2s 483ms/step - loss: 4.0549e-06 - acc: 1.0000 - val_loss: 1.2136e-04 - val_acc: 1.0000
# Epoch 9/15
# 4/4 [==============================] - 2s 484ms/step - loss: 3.1373e-06 - acc: 1.0000 - val_loss: 7.9661e-05 - val_acc: 1.0000
# Epoch 10/15
# 4/4 [==============================] - 2s 491ms/step - loss: 1.6238e-06 - acc: 1.0000 - val_loss: 5.0438e-05 - val_acc: 1.0000
# Epoch 11/15
# 4/4 [==============================] - 2s 492ms/step - loss: 9.9460e-07 - acc: 1.0000 - val_loss: 2.5965e-05 - val_acc: 1.0000
# Epoch 12/15
# 4/4 [==============================] - 2s 479ms/step - loss: 5.3926e-07 - acc: 1.0000 - val_loss: 1.3378e-05 - val_acc: 1.0000
# Epoch 13/15
# 4/4 [==============================] - 2s 484ms/step - loss: 2.6664e-07 - acc: 1.0000 - val_loss: 7.6833e-06 - val_acc: 1.0000
# Epoch 14/15
# 4/4 [==============================] - 2s 479ms/step - loss: 1.5712e-07 - acc: 1.0000 - val_loss: 4.9351e-06 - val_acc: 1.0000
# Epoch 15/15
# 4/4 [==============================] - 2s 476ms/step - loss: 9.4893e-08 - acc: 1.0000 - val_loss: 3.5339e-06 - val_acc: 1.0000

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 15), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 15), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 15), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 15), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        10
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
